# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
np.random.seed(1)
# Out:
# None

# %%
x= np.random.randint (0,50,1000)
y=-x+ np.random.randint(0,50,1000)

np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.71883093],
#        [-0.71883093,  1.        ]])

# %%
plt.scatter(x, y)
