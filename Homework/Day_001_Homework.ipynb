# %%
#1
---我選的題目為：Forest Cover Type (Kernels Only)  Use cartographic variables to classify forest categories
    資料為美國科羅拉多州羅斯福國家公園中四個野生森林區域，範圍為30x30公尺之大，而資料來源為美國羅斯福國家公園當局所提
    所提供。
    資料屬於結構式資料，包含了海拔高度、坡度、水文距離、土壤型態、與覆蓋型態....等等資料
    而他們想利用地圖變數來分類不同的森林覆蓋種類，想運用的方法是Kenel，也有許多其他方法像是EDA、Baseline...等等---
# Out:
#   File "<ipython-input-1-5eb7ffc5a7cc>", line 2
#     我選的題目為：Forest Cover Type (Kernels Only)  Use cartographic variables to classify forest categories
#                 ^
# SyntaxError: invalid character in identifier

# %%
#2
1. 核心問題： 想要提升業績，期望計畫實施後整理業績提升20%
2. 資料從何而來： 1. 搭乘時間： 由公司員工載客時間紀錄產生資料
                         2. 搭乘地點： 由公司員工載客上車地點紀錄產生資料
                         3. 乘客年齡： 由乘客預定時留下的紀錄產生資料
                         4. 服務品質： 由乘客的評論與星數產生資料
                         5. 距離與價格： 由乘客願意搭乘距離的總數紀錄
                        
3. 採用結構式資料 (包含上述五項的欄位)
4. 資料透過回歸式與假設檢定判斷何者為影響乘客意願的變因。
# Out:
#   File "<ipython-input-2-7b6a14439c06>", line 2
#     1. 核心問題： 想要提升業績，期望計畫實施後整理業績提升20%
#            ^
# SyntaxError: invalid character in identifier

# %%
#3
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
     MSE=mse=np.sum((y - yp)**2) / len(yp)
     return mse

def mean_absolute_error(y, yp):

    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 173.057
# The Mean absolute error is 10.579
