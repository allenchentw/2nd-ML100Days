# %%
import numpy as np
import os
import pandas as pd

# %%
dir_data='./Data/home-credit-default-risk/'
f_app_train= os.path.join(dir_data,'application_train.csv')
app_train = pd.read_csv(f_app_train)

# %%
app_train.describe()
# Out:
#           SK_ID_CURR        TARGET  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count   65499.000000  65499.000000  65499.000000      6.549900e+04
# mean   137986.370158      0.080551      0.419411      1.697625e+05
# std     21882.306074      0.272146      0.724368      4.668740e+05
# min    100002.000000      0.000000      0.000000      2.565000e+04
# 25%    119098.500000      0.000000      0.000000      1.125000e+05
# 50%    137956.000000      0.000000      0.000000      1.440000e+05
# 75%    156875.500000      0.000000      1.000000      2.025000e+05
# max    175957.000000      1.000000     11.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  6.549900e+04   65494.000000     6.544600e+04
# mean   5.993744e+05   27073.572327     5.386597e+05
# std    4.026647e+05   14487.004992     3.699266e+05
# min    4.500000e+04    2052.000000     4.500000e+04
# 25%    2.700000e+05   16456.500000     2.385000e+05
# 50%    5.135310e+05   24903.000000     4.500000e+05
# 75%    8.086500e+05   34587.000000     6.795000e+05
# max    4.050000e+06  258025.500000     4.050000e+06
#
#        REGION_POPULATION_RELATIVE    DAYS_BIRTH  DAYS_EMPLOYED  \
# count                65499.000000  65499.000000   65499.000000
# mean                     0.020867 -16027.294692   63224.604635
# std                      0.013767   4361.907096  140795.498287
# min                      0.000533 -25201.000000  -17531.000000
# 25%                      0.010006 -19657.000000   -2784.000000
# 50%                      0.018850 -15750.000000   -1217.000000
# 75%                      0.028663 -12390.000000    -289.000000
# max                      0.072508  -7676.000000  365243.000000
#
#                   ...              FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  \
# count             ...                  65499.000000      65499.000000
# mean              ...                      0.008321          0.000718
# std               ...                      0.090838          0.026778
# min               ...                      0.000000          0.000000
# 25%               ...                      0.000000          0.000000
# 50%               ...                      0.000000          0.000000
# 75%               ...                      0.000000          0.000000
# max               ...                      1.000000          1.000000
#
#        FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# count      65499.000000      65499.000000                56714.000000
# mean           0.000458          0.000321                    0.007106
# std            0.021397          0.017903                    0.088694
# min            0.000000          0.000000                    0.000000
# 25%            0.000000          0.000000                    0.000000
# 50%            0.000000          0.000000                    0.000000
# 75%            0.000000          0.000000                    0.000000
# max            1.000000          1.000000                    3.000000
#
#        AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# count               56714.000000                56714.000000
# mean                    0.007635                    0.033008
# std                     0.110756                    0.199280
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     0.000000                    0.000000
# max                     6.000000                    6.000000
#
#        AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# count               56714.000000               56714.000000
# mean                    0.269034                   0.263885
# std                     0.924256                   0.611959
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    24.000000                   8.000000
#
#        AMT_REQ_CREDIT_BUREAU_YEAR
# count                56714.000000
# mean                     1.885266
# std                      1.869598
# min                      0.000000
# 25%                      0.000000
# 50%                      1.000000
# 75%                      3.000000
# max                     25.000000
#
# [8 rows x 106 columns]

# %%
app_train['AMT_ANNUITY'].mean()
app_train['AMT_ANNUITY'].var()
# Out:
# 209873313.64256278

# %%
import matplotlib.pyplot as plt
app_train['AMT_ANNUITY'].hist(bins=50)
